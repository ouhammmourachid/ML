# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('./pointsSVM.csv', sep=';')
df = np.array(df)
X = df[:,0:2]
y = df[:,2]
axes = plt.axes()
axes.grid()
plt.scatter(X[y==+1][:,0],X[y==+1][:,1], color='r')
plt.scatter(X[y==-1][:,0],X[y==-1][:,1], color='b')
