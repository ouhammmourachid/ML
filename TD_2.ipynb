# %% [markdown]
# ## TP 2:
# #### 1 - import the libraries :

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %% [markdown]
# #### 2 - load the dataset :

# %%
data = pd.read_csv("univariate_linear_regression_dataset.csv",names=["X","Y"])
data
# Out:
#           X         Y
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# #### 3 - visualisation dataset:

# %%
plt.figure(figsize=(8,6))
plt.title("the visulisation of data of regresion:")
sns.scatterplot(x=data.X,y=data.Y)
plt.xlabel(" the X axis")
plt.ylabel(" the Y axis")
# Out:
# Text(0, 0.5, ' the Y axis')

# %%
SL = stats.linregress(data.X,data.Y)
slope:float = SL.slope
coef_correlation:float= SL.rvalue
intercept :float=SL.intercept
def predict(x:float)->float:
    return slope*x+intercept

# %%
axes = plt.axes()
axes.grid()
plt.scatter(data.X,data.Y)
fitline = predict(data.X)
plt.plot(data.X,fitline,c='r')
plt.show()

# %%
x :float = 22.5
f'the prediction of x = {x} is {predict(x)}'
# Out:
# 'the prediction of x = 22.5 is 22.94747611595401'
